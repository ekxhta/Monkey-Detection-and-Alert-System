# %%
#Install YOLOv8
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 38.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Mount drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load model

from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/Monkey.v11-noaugmentation.yolov8/best.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Import Libraries

from ultralytics import YOLO
import cv2
from IPython.display import display, Image
import os

# %%
# Load YOLOv8 model
model = YOLO("/content/drive/MyDrive/Monkey.v11-noaugmentation.yolov8/best.pt")

# %%
# Run validation
metrics = model.val()

# Print key metrics
print(f"Precision: {metrics.box.precision:.4f}")
print(f"Recall: {metrics.box.recall:.4f}")
print(f"mAP@0.5: {metrics.box.map50:.4f}")
print(f"mAP@0.5:0.95: {metrics.box.map:.4f}")
# Out:
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 11.5±6.6 MB/s, size: 45.7 KB)
# val: Scanning /content/drive/MyDrive/Monkey.v11-noaugmentation.yolov8/valid/labels.cache... 673 images, 122 backgrounds, 0 corrupt: 100%|██████████| 673/673 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 43/43 [52:39<00:00, 73.48s/it]
#                    all        673        707      0.906      0.843      0.915       0.65
# Speed: 7.6ms preprocess, 4664.1ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e1455306827d> in <cell line: 0>()
#       3
#       4 # Print key metrics
# ...

# %%
from IPython.display import Image

Image('runs/val/exp/confusion_matrix.png')
Image('runs/val/exp/PR_curve.png')
Image('runs/val/exp/F1_curve.png')
Image('runs/val/exp/confidence_curve.png')

# %%
# Set up video path
video_path = "/content/drive/MyDrive/Minor/Mischievous_Monkeys_Take_Over_Government_Buildings_in_India.mp4"

# %%
# Run detection on the video and save the output
model.predict(
    source=video_path,
    conf=0.3,
    save=True,
    save_txt=False,
    save_conf=True,
    stream=False  # Not real-time - full video processing
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2656) /content/drive/MyDrive/Minor/Mischievous_Monkeys_Take_Over_Government_Buildings_in_India.mp4: 384x640 3 Monkeys, 1891.4ms
# video 1/1 (frame 2/2656) /content/drive/MyDrive/Minor/Mischievous_Monkeys_Take_Over_Government_Buildings_in_India.mp4: 384x640 3 Monkeys, 1695.2ms
# ...
